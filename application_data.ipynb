# %% [markdown]
# <a href="https://colab.research.google.com/github/grgfatta86/Exercise/blob/main/application_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/application_data.csv', index_col='SK_ID_CURR', parse_dates=True)

# %%
df
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
# ...            ...                ...         ...          ...
# 358611           0         Cash loans           M            Y
# 358612           0         Cash loans           M            Y
# 358613           0         Cash loans           F            N
# 358614           0         Cash loans           M            Y
# 358615           0         Cash loans           F            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202500.0    406597.5
# ...

# %%
df.columns
# Out:
# Index(['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=121)

# %%
categorical_vars = df.select_dtypes(include=['object', 'category'])
print(categorical_vars)
# Out:
#            NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# SK_ID_CURR
# 100002             Cash loans           M            N               Y
# 100003             Cash loans           F            N               N
# 100004        Revolving loans           M            Y               Y
# 100006             Cash loans           F            N               Y
# 100007             Cash loans           M            N               Y
# ...                       ...         ...          ...             ...
# 358611             Cash loans           M            Y               Y
# 358612             Cash loans           M            Y               Y
# 358613             Cash loans           F            N               N
# 358614             Cash loans           M            Y               N
# 358615             Cash loans           F            N               Y
#
#            NAME_TYPE_SUITE NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# ...

# %%
df.select_dtypes(include='number')
# Out:
#             TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100002           1             0          202500.0    406597.5      24700.5
# 100003           0             0          270000.0   1293502.5      35698.5
# 100004           0             0           67500.0    135000.0       6750.0
# 100006           0             0          135000.0    312682.5      29686.5
# 100007           0             0          121500.0    513000.0      21865.5
# ...            ...           ...               ...         ...          ...
# 358611           0             0          218250.0    269550.0      19300.5
# 358612           0             0          585000.0    312678.0      28809.0
# 358613           0             0           90000.0    364896.0      18760.5
# 358614           0             0          180000.0    178290.0      19048.5
# 358615           0             0          360000.0    573408.0      27585.0
#
# ...

# %%
df.select_dtypes(include='number')
# Out:
#             TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR
# 100002           1             0          202500.0    406597.5      24700.5
# 100003           0             0          270000.0   1293502.5      35698.5
# 100004           0             0           67500.0    135000.0       6750.0
# 100006           0             0          135000.0    312682.5      29686.5
# 100007           0             0          121500.0    513000.0      21865.5
# ...            ...           ...               ...         ...          ...
# 358611           0             0          218250.0    269550.0      19300.5
# 358612           0             0          585000.0    312678.0      28809.0
# 358613           0             0           90000.0    364896.0      18760.5
# 358614           0             0          180000.0    178290.0      19048.5
# 358615           0             0          360000.0    573408.0      27585.0
#
# ...

# %%
df.select_dtypes(exclude='number')
# Out:
#            NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# SK_ID_CURR
# 100002             Cash loans           M            N               Y
# 100003             Cash loans           F            N               N
# 100004        Revolving loans           M            Y               Y
# 100006             Cash loans           F            N               Y
# 100007             Cash loans           M            N               Y
# ...                       ...         ...          ...             ...
# 151719             Cash loans           M            N               Y
# 151720             Cash loans           F            N               Y
# 151721             Cash loans           F            N               Y
# 151722             Cash loans           F            Y               Y
# 151723             Cash loans           F            N               Y
#
#             NAME_TYPE_SUITE NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# ...

# %%
instances_counts = df['TARGET'].value_counts()
print(instances_counts)
# Out:
# 0    205172
# 1     18112
# Name: TARGET, dtype: int64

# %%
df.shape
# Out:
# (223284, 121)

# %%
instances_counts = df['TARGET'].value_counts()
total_instances = df.shape[0]
print(total_instances)
instances_percentages = instances_counts / total_instances * 100

print(instances_percentages)
# Out:
# 223284
# 0    91.888357
# 1     8.111643
# Name: TARGET, dtype: float64

# %%
unique_values=df[df.columns[:len(df)]].unique()
print(unique_values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-ba569ea561de> in <cell line: 1>()
# ----> 1 unique_values=df[df.columns[:len(df)]].unique()
#       2 print(unique_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
for column in df.columns:
    unique_values = df[column].unique()
    print(unique_values)
# Out:
# [1 0]
# ['Cash loans' 'Revolving loans']
# ['M' 'F' 'XNA']
# ['N' 'Y']
# ['Y' 'N']
# [ 0  1  2  3  4  7  5  6  8  9 11 12 10 19 14]
# [202500.    270000.     67500.    ...  56646.765 187222.5    44604.   ]
# [ 406597.5 1293502.5  135000.  ... 1996456.5 1089931.5  559035. ]
# [24700.5 35698.5  6750.  ...  4162.5 44523.  28809. ]
# [ 351000.  1129500.   135000.   297000.   513000.   454500.  1395000.
#  1530000.   913500.   405000.   652500.    67500.   697500.   679500.
#   247500.   387000.   270000.   157500.   427500.   927000.   450000.
#   225000.   702000.   675000.   180000.   477000.   360000.  1125000.
#   553500.   540000.   855000.   238500.   598500.   252000.  1350000.
#   666000.   202500.   517500.  1588500.  1080000.   810000.    90000.
#   315000.   900000.  1035000.   463500.   459000.   256500.   585000.
#   643500.   283500.   472500.   337500.   720000.   396000.    45000.
#  1089000.   319500.  1435500.   688500.   261000.   468000.   535500.
# ...

# %%
##Find how many nan values in each column
df.isna().sum()
# Out:
# TARGET                           0
# NAME_CONTRACT_TYPE               0
# CODE_GENDER                      0
# FLAG_OWN_CAR                     0
# FLAG_OWN_REALTY                  0
#                               ...
# AMT_REQ_CREDIT_BUREAU_DAY     6002
# AMT_REQ_CREDIT_BUREAU_WEEK    6002
# AMT_REQ_CREDIT_BUREAU_MON     6002
# AMT_REQ_CREDIT_BUREAU_QRT     6002
# AMT_REQ_CREDIT_BUREAU_YEAR    6002
# Length: 121, dtype: int64

# %%
# Preprocessing for each column differently according to the nan values in each column
df_with_0=df.fillna(0)
df_with_0
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
# ...            ...                ...         ...          ...
# 151719           0         Cash loans           M            N
# 151720           0         Cash loans           F            N
# 151721           0         Cash loans           F            N
# 151722           0         Cash loans           F            Y
# 151723           0         Cash loans           F            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202500.0    406597.5
# ...

# %%
df_with_mean=df[column].fillna(df[column].mean(), inplace=True)

df_with_mean

# %%
df

# %%
df[column].fillna(df[column].mode()[:0:len(df)])

# %%
df

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
from sklearn.impute import SimpleImputer
# sklearn.impute.SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

imputer.fit(X[:,12:17])
X[:,12:17]= imputer.transform(X[:,12:17])

# %% [markdown]
# 1) Find all categorical variables
#
# 2) Find Count of instances in 0 and 1 class
#
# 3) Find % of instances in 0 and 1 class
#
# 4) Bar chart for both 2nd and 3rd
#
# 5) Find unique values in each column

# %% [markdown]
# 6) Find how many nan values in each column
#
# 7) Preprocessing for each column differently according to the nan values in each column
